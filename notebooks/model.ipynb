# %%
import sys
import statsmodels.api as sm 
import pandas as pd
sys.path.append('..')

# %%
from src.model import run_glm_modeling
from src.hypothesis import perform_hypothesis_tests

# %%
df = pd.read_csv('../data/raw/MachineLearningRating_v3.txt' , sep='|',low_memory=False,encoding='latin1')
df_with_metrics = perform_hypothesis_tests(df)
# Out:
# --- A. Risk Difference Across Provinces (Claim Frequency) ---
# P-Value: 0.0000
#
# 1. PROVINCE RISK ADJUSTMENT:
#    • Gauteng has 2.7x higher claim rate than Northern Cape
#    • ACTION: Increase premiums in Gauteng by 10-15%
#    • ACTION: Target marketing toward Northern Cape for customer acquisition
# Decision: REJECT H₀. There IS a statistically significant risk difference across provinces.
# Insight: Province is a highly significant factor in predicting claim frequency.
#
# --- B. Risk Difference Between Zip Codes (Claim Frequency, Top 10) ---
# P-Value: 0.0000
# Decision: REJECT H₀. There IS a statistically significant risk difference between the top 10 zip codes.
# Insight: Geographic location at the zip code level is a strong predictor of claim frequency and must be segmented.
#
# --- C. Margin Difference Between Zip Codes (Profitability, Top 10) ---
# P-Value: 0.3964
# Decision: FAIL TO REJECT H₀. Margin differences are not statistically significant.
#
# --- D. Risk Difference Between Gender (Claim Frequency) ---
# P-Value: 0.9515
# Decision: FAIL TO REJECT H₀. No significant difference found.

# %%
print(df_with_metrics.columns.tolist())
# Out:
# ['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth', 'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet', 'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims', 'Claimed', 'Margin']

# %%
glm_results, final_rmse = run_glm_modeling(df_with_metrics)
# Out:
# c:\Users\arwa\insurance-risk-analysis\venv\Lib\site-packages\statsmodels\genmod\families\links.py:13: FutureWarning: The log link alias is deprecated. Use Log instead. The log link alias will be removed after the 0.15.0 release.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 glm_results, final_rmse = run_glm_modeling(df_with_metrics)
#
# File c:\Users\arwa\insurance-risk-analysis\notebooks\..\src\model.py:46, in run_glm_modeling(df)
#      42 X_train_const = sm.add_constant(X_train, prepend=False)
#      44 glm_model = GLM(Y_train, X_train_const,
#      45                 family=families.Gamma(link=families.links.log()))
# ---> 46 glm_results = glm_model.fit()
#      48 print("TASK 4: GAMMA GLM RESULTS (Loss Ratio)")
#      49 print(glm_results.summary())
#
# File c:\Users\arwa\insurance-risk-analysis\venv\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1192, in GLM.fit(self, start_params, maxiter, method, tol, scale, cov_type, cov_kwds, use_t, full_output, disp, max_start_irls, **kwargs)
#    1190     if cov_type.lower() == 'eim':
#    1191         cov_type = 'nonrobust'
# -> 1192     return self._fit_irls(start_params=start_params, maxiter=maxiter,
#    1193                           tol=tol, scale=scale, cov_type=cov_type,
#    1194                           cov_kwds=cov_kwds, use_t=use_t, **kwargs)
#    1195 else:
#    1196     self._optim_hessian = kwargs.get('optim_hessian')
#
# File c:\Users\arwa\insurance-risk-analysis\venv\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1333, in GLM._fit_irls(self, start_params, maxiter, tol, scale, cov_type, cov_kwds, use_t, **kwargs)
#    1328 wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
#    1329             - self._offset_exposure)
#    1330 wls_mod = reg_tools._MinimalWLS(wlsendog, wlsexog,
#    1331                                 self.weights, check_endog=True,
#    1332                                 check_weights=True)
# -> 1333 wls_results = wls_mod.fit(method=wls_method)
#    1334 lin_pred = np.dot(self.exog, wls_results.params)
#    1335 lin_pred += self._offset_exposure
#
# File c:\Users\arwa\insurance-risk-analysis\venv\Lib\site-packages\statsmodels\regression\_tools.py:101, in _MinimalWLS.fit(self, method)
#      99     params = np.linalg.solve(R, np.dot(Q.T, self.wendog))
#     100 else:
# --> 101     params, _, _, _ = np.linalg.lstsq(self.wexog, self.wendog,
#     102                                       rcond=-1)
#     103 return self.results(params)
#
# File c:\Users\arwa\insurance-risk-analysis\venv\Lib\site-packages\numpy\linalg\_linalg.py:2564, in lstsq(a, b, rcond)
#    2560     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
#    2562 with errstate(call=_raise_linalgerror_lstsq, invalid='call',
#    2563               over='ignore', divide='ignore', under='ignore'):
# -> 2564     x, resids, rank, s = _umath_linalg.lstsq(a, b, rcond,
#    2565                                              signature=signature)
#    2566 if m == 0:
#    2567     x[...] = 0
#
# MemoryError:
